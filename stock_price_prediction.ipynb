# %% [markdown]
# <a href="https://colab.research.google.com/github/clawnic/stock-prediction-lstm/blob/main/stock_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
stock_data = pd.read_csv('Netflix_Dataset.csv', index_col='Date')
stock_data.head()
# Out:
#               Open    High     Low   Close     Volume
# Date
# 04-03-2019  359.72  362.25  348.04  351.04  74,86,996
# 05-03-2019  351.46  356.17  348.25  354.30  59,37,754
# 06-03-2019  353.60  359.88  351.70  359.61  62,11,895
# 07-03-2019  360.16  362.86  350.50  352.60  61,51,331
# 08-03-2019  345.75  349.92  342.47  349.60  68,98,838

# %%
stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 758 entries, 04-03-2019 to 03-03-2022
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    758 non-null    float64
#  1   High    758 non-null    float64
#  2   Low     758 non-null    float64
#  3   Close   758 non-null    float64
#  4   Volume  758 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 35.5+ KB

# %% [markdown]
# Assuming 'stock_data' has a 'Date' column or is using Date as the index

# %%
plt.figure(figsize=(10, 6))
plt.plot(stock_data['High'] , label='High',linewidth=2)
plt.plot(stock_data['Low'] , label='Low',linewidth=2)
# Adding labels and title
plt.title('Stock High and Low Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
#rotating x axis labels by 45 deg to avoid overlap
plt.xticks(rotation=45)
# Optionally, limit the number of x-ticks for better readability
plt.xticks(stock_data.index[::len(stock_data)//10])  # Adjust the step size based on your data size
# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(stock_data['Open'],label='Open',linewidth=2)
plt.plot(stock_data['Close'],label='Close',linewidth=1)
plt.title('Stock Open and Close Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.legend()
plt.xticks(rotation=45)
plt.xticks(stock_data.index[::len(stock_data)//10])
plt.show()

# %% [markdown]
# Importing Libary

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import TimeSeriesSplit
import matplotlib.pyplot as plt

# %% [markdown]
# Data Processing

# %%
target_y = stock_data['Close']

X_feat = stock_data.iloc[:,0:3]

stock_data = stock_data[['Open', 'High', 'Low', 'Close']]

# %% [markdown]
# Feature Scaling

# %%
sc = StandardScaler()
stock_data_ft = sc.fit_transform(stock_data.values)
stock_data_ft = pd.DataFrame(columns=stock_data.columns,data=stock_data_ft,index=stock_data.index)

# %% [markdown]
# Training and test data split

# %%
def lstm_split(data, n_steps):
    X, y = [], []
    for i in range(len(data) - n_steps):
        # Extract a window of size `n_steps` for features
        X.append(data[i:i + n_steps, :-1])  # All but last column
        # Extract the `n_steps`-th target value
        y.append(data[i + n_steps - 1, -1])  # Target value (last column)
    return np.array(X), np.array(y)

# %%
X1, y1 = lstm_split(stock_data_ft.values, n_steps=1)
train_split=0.8
split_idx= int(np.ceil(len(X1)*train_split))
date_index = stock_data_ft.index
X_train, X_test = X1[:split_idx], X1[split_idx:]
y_train, y_test = y1[:split_idx], y1[split_idx:]
X_train_date, X_test_date = date_index[:split_idx], date_index[split_idx:]
print(X1. shape, X_train. shape, X_test.shape, y_test.shape)
# Out:
# (757, 1, 3) (606, 1, 3) (151, 1, 3) (151,)

# %% [markdown]
# LSTM Model

# %%
# Define LSTM Model

lstm = Sequential()

# LSTM Layer (Set return_sequences=False if you want one output per sample)

lstm.add(LSTM(32, input_shape=(X_train.shape[1], X_train.shape[2]), activation='relu', return_sequences=True))

# Output Layer

lstm.add(Dense(1))

# Compile the Model

lstm.compile(loss='mean_squared_error', optimizer='adam')

# Print Model Summary

lstm.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 1, 32)          │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1, 1)           │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,641 (18.13 KB)
#  Trainable params: 4,641 (18.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = lstm.fit(X_train, y_train, epochs=100, batch_size=4, validation_split=0.2, verbose=2, shuffle=False)
# Out:
# Epoch 1/100
# 121/121 - 3s - 27ms/step - loss: 0.5387 - val_loss: 0.2638
# Epoch 2/100
# 121/121 - 1s - 6ms/step - loss: 0.1159 - val_loss: 0.0456
# Epoch 3/100
# 121/121 - 0s - 3ms/step - loss: 0.0133 - val_loss: 0.0091
# Epoch 4/100
# 121/121 - 0s - 3ms/step - loss: 0.0129 - val_loss: 0.0088
# Epoch 5/100
# 121/121 - 0s - 3ms/step - loss: 0.0128 - val_loss: 0.0088
# Epoch 6/100
# 121/121 - 1s - 6ms/step - loss: 0.0127 - val_loss: 0.0089
# Epoch 7/100
# 121/121 - 1s - 5ms/step - loss: 0.0125 - val_loss: 0.0089
# Epoch 8/100
# 121/121 - 0s - 4ms/step - loss: 0.0124 - val_loss: 0.0090
# Epoch 9/100
# 121/121 - 1s - 5ms/step - loss: 0.0124 - val_loss: 0.0091
# Epoch 10/100
# 121/121 - 0s - 4ms/step - loss: 0.0123 - val_loss: 0.0092
# Epoch 11/100
# 121/121 - 0s - 4ms/step - loss: 0.0123 - val_loss: 0.0092
# Epoch 12/100
# 121/121 - 0s - 3ms/step - loss: 0.0122 - val_loss: 0.0092
# Epoch 13/100
# 121/121 - 0s - 3ms/step - loss: 0.0122 - val_loss: 0.0093
# Epoch 14/100
# 121/121 - 0s - 4ms/step - loss: 0.0122 - val_loss: 0.0093
# Epoch 15/100
# 121/121 - 1s - 6ms/step - loss: 0.0121 - val_loss: 0.0092
# Epoch 16/100
# 121/121 - 1s - 5ms/step - loss: 0.0121 - val_loss: 0.0092
# Epoch 17/100
# 121/121 - 0s - 3ms/step - loss: 0.0121 - val_loss: 0.0092
# Epoch 18/100
# 121/121 - 1s - 6ms/step - loss: 0.0121 - val_loss: 0.0092
# Epoch 19/100
# 121/121 - 1s - 4ms/step - loss: 0.0120 - val_loss: 0.0091
# Epoch 20/100
# 121/121 - 1s - 5ms/step - loss: 0.0120 - val_loss: 0.0091
# Epoch 21/100
# 121/121 - 1s - 5ms/step - loss: 0.0120 - val_loss: 0.0090
# Epoch 22/100
# 121/121 - 1s - 6ms/step - loss: 0.0120 - val_loss: 0.0090
# Epoch 23/100
# 121/121 - 1s - 9ms/step - loss: 0.0120 - val_loss: 0.0090
# Epoch 24/100
# 121/121 - 1s - 5ms/step - loss: 0.0119 - val_loss: 0.0090
# Epoch 25/100
# 121/121 - 0s - 3ms/step - loss: 0.0119 - val_loss: 0.0089
# Epoch 26/100
# 121/121 - 1s - 6ms/step - loss: 0.0119 - val_loss: 0.0089
# Epoch 27/100
# 121/121 - 1s - 5ms/step - loss: 0.0119 - val_loss: 0.0089
# Epoch 28/100
# 121/121 - 1s - 6ms/step - loss: 0.0119 - val_loss: 0.0088
# Epoch 29/100
# 121/121 - 1s - 4ms/step - loss: 0.0118 - val_loss: 0.0088
# Epoch 30/100
# 121/121 - 1s - 5ms/step - loss: 0.0118 - val_loss: 0.0088
# Epoch 31/100
# 121/121 - 1s - 5ms/step - loss: 0.0119 - val_loss: 0.0087
# Epoch 32/100
# 121/121 - 1s - 6ms/step - loss: 0.0119 - val_loss: 0.0087
# Epoch 33/100
# 121/121 - 1s - 5ms/step - loss: 0.0119 - val_loss: 0.0087
# Epoch 34/100
# 121/121 - 1s - 5ms/step - loss: 0.0119 - val_loss: 0.0087
# Epoch 35/100
# 121/121 - 1s - 4ms/step - loss: 0.0119 - val_loss: 0.0087
# Epoch 36/100
# 121/121 - 0s - 4ms/step - loss: 0.0119 - val_loss: 0.0087
# Epoch 37/100
# 121/121 - 0s - 3ms/step - loss: 0.0119 - val_loss: 0.0087
# Epoch 38/100
# 121/121 - 0s - 4ms/step - loss: 0.0119 - val_loss: 0.0087
# Epoch 39/100
# 121/121 - 0s - 3ms/step - loss: 0.0119 - val_loss: 0.0086
# Epoch 40/100
# 121/121 - 1s - 5ms/step - loss: 0.0119 - val_loss: 0.0086
# Epoch 41/100
# 121/121 - 1s - 6ms/step - loss: 0.0119 - val_loss: 0.0086
# Epoch 42/100
# 121/121 - 1s - 6ms/step - loss: 0.0119 - val_loss: 0.0086
# Epoch 43/100
# 121/121 - 1s - 8ms/step - loss: 0.0119 - val_loss: 0.0086
# Epoch 44/100
# 121/121 - 1s - 5ms/step - loss: 0.0120 - val_loss: 0.0086
# Epoch 45/100
# 121/121 - 0s - 3ms/step - loss: 0.0120 - val_loss: 0.0086
# Epoch 46/100
# 121/121 - 1s - 6ms/step - loss: 0.0120 - val_loss: 0.0086
# Epoch 47/100
# 121/121 - 0s - 4ms/step - loss: 0.0120 - val_loss: 0.0086
# Epoch 48/100
# 121/121 - 0s - 4ms/step - loss: 0.0120 - val_loss: 0.0086
# Epoch 49/100
# 121/121 - 0s - 4ms/step - loss: 0.0121 - val_loss: 0.0086
# Epoch 50/100
# 121/121 - 0s - 4ms/step - loss: 0.0122 - val_loss: 0.0085
# Epoch 51/100
# 121/121 - 0s - 4ms/step - loss: 0.0122 - val_loss: 0.0085
# Epoch 52/100
# 121/121 - 1s - 6ms/step - loss: 0.0123 - val_loss: 0.0085
# Epoch 53/100
# 121/121 - 0s - 3ms/step - loss: 0.0124 - val_loss: 0.0085
# Epoch 54/100
# 121/121 - 0s - 3ms/step - loss: 0.0126 - val_loss: 0.0085
# Epoch 55/100
# 121/121 - 0s - 3ms/step - loss: 0.0128 - val_loss: 0.0085
# Epoch 56/100
# 121/121 - 0s - 3ms/step - loss: 0.0130 - val_loss: 0.0085
# Epoch 57/100
# 121/121 - 1s - 5ms/step - loss: 0.0132 - val_loss: 0.0085
# Epoch 58/100
# 121/121 - 0s - 4ms/step - loss: 0.0135 - val_loss: 0.0085
# Epoch 59/100
# 121/121 - 0s - 3ms/step - loss: 0.0139 - val_loss: 0.0085
# Epoch 60/100
# 121/121 - 1s - 6ms/step - loss: 0.0143 - val_loss: 0.0085
# Epoch 61/100
# 121/121 - 0s - 3ms/step - loss: 0.0147 - val_loss: 0.0085
# Epoch 62/100
# 121/121 - 0s - 3ms/step - loss: 0.0151 - val_loss: 0.0085
# Epoch 63/100
# 121/121 - 1s - 6ms/step - loss: 0.0155 - val_loss: 0.0085
# Epoch 64/100
# 121/121 - 1s - 7ms/step - loss: 0.0158 - val_loss: 0.0085
# Epoch 65/100
# 121/121 - 1s - 10ms/step - loss: 0.0161 - val_loss: 0.0085
# Epoch 66/100
# 121/121 - 1s - 9ms/step - loss: 0.0162 - val_loss: 0.0085
# Epoch 67/100
# 121/121 - 0s - 4ms/step - loss: 0.0163 - val_loss: 0.0085
# Epoch 68/100
# 121/121 - 1s - 5ms/step - loss: 0.0162 - val_loss: 0.0085
# Epoch 69/100
# 121/121 - 0s - 3ms/step - loss: 0.0161 - val_loss: 0.0085
# Epoch 70/100
# 121/121 - 0s - 4ms/step - loss: 0.0159 - val_loss: 0.0085
# Epoch 71/100
# 121/121 - 0s - 3ms/step - loss: 0.0157 - val_loss: 0.0085
# Epoch 72/100
# 121/121 - 1s - 6ms/step - loss: 0.0154 - val_loss: 0.0085
# Epoch 73/100
# 121/121 - 0s - 3ms/step - loss: 0.0152 - val_loss: 0.0085
# Epoch 74/100
# 121/121 - 1s - 5ms/step - loss: 0.0150 - val_loss: 0.0084
# Epoch 75/100
# 121/121 - 0s - 3ms/step - loss: 0.0147 - val_loss: 0.0084
# Epoch 76/100
# 121/121 - 1s - 4ms/step - loss: 0.0145 - val_loss: 0.0084
# Epoch 77/100
# 121/121 - 1s - 4ms/step - loss: 0.0143 - val_loss: 0.0084
# Epoch 78/100
# 121/121 - 0s - 4ms/step - loss: 0.0142 - val_loss: 0.0084
# Epoch 79/100
# 121/121 - 1s - 5ms/step - loss: 0.0140 - val_loss: 0.0084
# Epoch 80/100
# 121/121 - 1s - 4ms/step - loss: 0.0139 - val_loss: 0.0083
# Epoch 81/100
# 121/121 - 0s - 3ms/step - loss: 0.0138 - val_loss: 0.0083
# Epoch 82/100
# 121/121 - 0s - 3ms/step - loss: 0.0136 - val_loss: 0.0083
# Epoch 83/100
# 121/121 - 0s - 3ms/step - loss: 0.0136 - val_loss: 0.0083
# Epoch 84/100
# 121/121 - 1s - 6ms/step - loss: 0.0135 - val_loss: 0.0083
# Epoch 85/100
# 121/121 - 1s - 6ms/step - loss: 0.0134 - val_loss: 0.0083
# Epoch 86/100
# 121/121 - 1s - 5ms/step - loss: 0.0134 - val_loss: 0.0083
# Epoch 87/100
# 121/121 - 1s - 6ms/step - loss: 0.0133 - val_loss: 0.0083
# Epoch 88/100
# 121/121 - 1s - 8ms/step - loss: 0.0133 - val_loss: 0.0083
# Epoch 89/100
# 121/121 - 1s - 5ms/step - loss: 0.0132 - val_loss: 0.0083
# Epoch 90/100
# 121/121 - 1s - 4ms/step - loss: 0.0132 - val_loss: 0.0082
# Epoch 91/100
# 121/121 - 1s - 5ms/step - loss: 0.0132 - val_loss: 0.0082
# Epoch 92/100
# 121/121 - 0s - 3ms/step - loss: 0.0132 - val_loss: 0.0082
# Epoch 93/100
# 121/121 - 0s - 4ms/step - loss: 0.0132 - val_loss: 0.0082
# Epoch 94/100
# 121/121 - 1s - 4ms/step - loss: 0.0132 - val_loss: 0.0082
# Epoch 95/100
# 121/121 - 1s - 6ms/step - loss: 0.0132 - val_loss: 0.0082
# Epoch 96/100
# 121/121 - 1s - 5ms/step - loss: 0.0132 - val_loss: 0.0082
# Epoch 97/100
# 121/121 - 1s - 5ms/step - loss: 0.0132 - val_loss: 0.0082
# Epoch 98/100
# 121/121 - 1s - 5ms/step - loss: 0.0132 - val_loss: 0.0082
# Epoch 99/100
# 121/121 - 1s - 5ms/step - loss: 0.0132 - val_loss: 0.0082
# Epoch 100/100
# 121/121 - 1s - 5ms/step - loss: 0.0132 - val_loss: 0.0082

# %% [markdown]
# Training Loss Plot

# %%
# Plot the training loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss', color='blue', linewidth=2)
# Annotating the plot
plt.title('Training Loss vs. Epochs', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# Performance Evaluation

# %%
y_pred = lstm.predict(X_test)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step

# %%
#If n = 1
# Ensure y_test is squeezed (flattened) if it has an extra dimension

y_test_flat = y_test.squeeze()

y_pred_flat = y_pred.squeeze()

# Plot the true values and predictions

plt.figure(figsize=(12, 6))

plt.plot(y_test_flat, label="True Values", color="green", linewidth=2)

plt.plot(y_pred_flat, label="LSTM Predictions", color="red", linewidth=2)

# Add labels, title, and legend

plt.title("LSTM Predictions vs. True Values", fontsize=16)

plt.xlabel("Time Step", fontsize=14)

plt.ylabel("Value", fontsize=14)

plt.legend(fontsize=12)

plt.grid(True)

# Show the plot

plt.show()

# %% [markdown]
# Performance indicator

# %%
mse = mean_squared_error(y_test, y_pred_flat)

rmse = np.sqrt(mse)

mape = mean_absolute_percentage_error(y_test, y_pred_flat)

print("RMSE: ",rmse)

print("MAPE: ", mape)
# Out:
# RMSE:  0.1386092045892404
# MAPE:  0.11067501248364958

# %% [markdown]
# Trying another model by adding LSTM layer

# %%
lstm = Sequential()

lstm.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]),

              activation='relu', return_sequences=True))

lstm.add(LSTM(50, activation='relu', return_sequences=True))

lstm.add(LSTM(50, activation='relu'))

lstm.add(Dense(1))

lstm.compile(loss='mean_squared_error', optimizer='adam')

lstm.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 1, 50)          │        10,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 1, 50)          │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 51,251 (200.20 KB)
#  Trainable params: 51,251 (200.20 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history=lstm.fit(X_train, y_train,epochs=100, batch_size=4,verbose=2, shuffle=False)
y_pred = lstm.predict(X_test)
# Out:
# Epoch 1/100
# 152/152 - 3s - 22ms/step - loss: 0.6434
# Epoch 2/100
# 152/152 - 1s - 4ms/step - loss: 0.0297
# Epoch 3/100
# 152/152 - 1s - 4ms/step - loss: 0.0118
# Epoch 4/100
# 152/152 - 1s - 8ms/step - loss: 0.0095
# Epoch 5/100
# 152/152 - 1s - 4ms/step - loss: 0.0083
# Epoch 6/100
# 152/152 - 2s - 11ms/step - loss: 0.0075
# Epoch 7/100
# 152/152 - 1s - 7ms/step - loss: 0.0069
# Epoch 8/100
# 152/152 - 1s - 5ms/step - loss: 0.0063
# Epoch 9/100
# 152/152 - 1s - 4ms/step - loss: 0.0059
# Epoch 10/100
# 152/152 - 1s - 5ms/step - loss: 0.0055
# Epoch 11/100
# 152/152 - 1s - 4ms/step - loss: 0.0052
# Epoch 12/100
# 152/152 - 1s - 5ms/step - loss: 0.0050
# Epoch 13/100
# 152/152 - 1s - 8ms/step - loss: 0.0048
# Epoch 14/100
# 152/152 - 1s - 8ms/step - loss: 0.0047
# Epoch 15/100
# 152/152 - 1s - 4ms/step - loss: 0.0046
# Epoch 16/100
# 152/152 - 1s - 8ms/step - loss: 0.0046
# Epoch 17/100
# 152/152 - 1s - 5ms/step - loss: 0.0046
# Epoch 18/100
# 152/152 - 1s - 8ms/step - loss: 0.0045
# Epoch 19/100
# 152/152 - 2s - 11ms/step - loss: 0.0043
# Epoch 20/100
# 152/152 - 1s - 7ms/step - loss: 0.0042
# Epoch 21/100
# 152/152 - 1s - 8ms/step - loss: 0.0039
# Epoch 22/100
# 152/152 - 1s - 4ms/step - loss: 0.0040
# Epoch 23/100
# 152/152 - 1s - 5ms/step - loss: 0.0039
# Epoch 24/100
# 152/152 - 1s - 5ms/step - loss: 0.0039
# Epoch 25/100
# 152/152 - 1s - 8ms/step - loss: 0.0038
# Epoch 26/100
# 152/152 - 1s - 5ms/step - loss: 0.0036
# Epoch 27/100
# 152/152 - 1s - 4ms/step - loss: 0.0036
# Epoch 28/100
# 152/152 - 1s - 8ms/step - loss: 0.0034
# Epoch 29/100
# 152/152 - 1s - 8ms/step - loss: 0.0035
# Epoch 30/100
# 152/152 - 1s - 5ms/step - loss: 0.0034
# Epoch 31/100
# 152/152 - 2s - 10ms/step - loss: 0.0033
# Epoch 32/100
# 152/152 - 1s - 7ms/step - loss: 0.0031
# Epoch 33/100
# 152/152 - 1s - 6ms/step - loss: 0.0030
# Epoch 34/100
# 152/152 - 1s - 4ms/step - loss: 0.0030
# Epoch 35/100
# 152/152 - 1s - 4ms/step - loss: 0.0028
# Epoch 36/100
# 152/152 - 1s - 4ms/step - loss: 0.0028
# Epoch 37/100
# 152/152 - 1s - 9ms/step - loss: 0.0027
# Epoch 38/100
# 152/152 - 1s - 8ms/step - loss: 0.0026
# Epoch 39/100
# 152/152 - 1s - 5ms/step - loss: 0.0025
# Epoch 40/100
# 152/152 - 1s - 8ms/step - loss: 0.0025
# Epoch 41/100
# 152/152 - 1s - 8ms/step - loss: 0.0025
# Epoch 42/100
# 152/152 - 1s - 5ms/step - loss: 0.0024
# Epoch 43/100
# 152/152 - 1s - 9ms/step - loss: 0.0024
# Epoch 44/100
# 152/152 - 1s - 7ms/step - loss: 0.0025
# Epoch 45/100
# 152/152 - 1s - 7ms/step - loss: 0.0025
# Epoch 46/100
# 152/152 - 1s - 6ms/step - loss: 0.0028
# Epoch 47/100
# 152/152 - 1s - 5ms/step - loss: 0.0030
# Epoch 48/100
# 152/152 - 1s - 4ms/step - loss: 0.0028
# Epoch 49/100
# 152/152 - 1s - 4ms/step - loss: 0.0025
# Epoch 50/100
# 152/152 - 1s - 9ms/step - loss: 0.0024
# Epoch 51/100
# 152/152 - 1s - 8ms/step - loss: 0.0024
# Epoch 52/100
# 152/152 - 1s - 5ms/step - loss: 0.0023
# Epoch 53/100
# 152/152 - 1s - 8ms/step - loss: 0.0023
# Epoch 54/100
# 152/152 - 1s - 5ms/step - loss: 0.0022
# Epoch 55/100
# 152/152 - 1s - 4ms/step - loss: 0.0022
# Epoch 56/100
# 152/152 - 1s - 8ms/step - loss: 0.0022
# Epoch 57/100
# 152/152 - 2s - 10ms/step - loss: 0.0022
# Epoch 58/100
# 152/152 - 1s - 7ms/step - loss: 0.0022
# Epoch 59/100
# 152/152 - 1s - 7ms/step - loss: 0.0022
# Epoch 60/100
# 152/152 - 1s - 5ms/step - loss: 0.0022
# Epoch 61/100
# 152/152 - 1s - 5ms/step - loss: 0.0023
# Epoch 62/100
# 152/152 - 1s - 8ms/step - loss: 0.0023
# Epoch 63/100
# 152/152 - 1s - 5ms/step - loss: 0.0023
# Epoch 64/100
# 152/152 - 1s - 4ms/step - loss: 0.0023
# Epoch 65/100
# 152/152 - 1s - 4ms/step - loss: 0.0023
# Epoch 66/100
# 152/152 - 1s - 6ms/step - loss: 0.0022
# Epoch 67/100
# 152/152 - 1s - 7ms/step - loss: 0.0022
# Epoch 68/100
# 152/152 - 1s - 7ms/step - loss: 0.0021
# Epoch 69/100
# 152/152 - 2s - 11ms/step - loss: 0.0021
# Epoch 70/100
# 152/152 - 1s - 8ms/step - loss: 0.0021
# Epoch 71/100
# 152/152 - 1s - 5ms/step - loss: 0.0021
# Epoch 72/100
# 152/152 - 1s - 8ms/step - loss: 0.0021
# Epoch 73/100
# 152/152 - 1s - 8ms/step - loss: 0.0021
# Epoch 74/100
# 152/152 - 1s - 8ms/step - loss: 0.0021
# Epoch 75/100
# 152/152 - 1s - 5ms/step - loss: 0.0021
# Epoch 76/100
# 152/152 - 1s - 5ms/step - loss: 0.0021
# Epoch 77/100
# 152/152 - 1s - 8ms/step - loss: 0.0020
# Epoch 78/100
# 152/152 - 1s - 8ms/step - loss: 0.0020
# Epoch 79/100
# 152/152 - 1s - 8ms/step - loss: 0.0020
# Epoch 80/100
# 152/152 - 1s - 4ms/step - loss: 0.0020
# Epoch 81/100
# 152/152 - 2s - 10ms/step - loss: 0.0020
# Epoch 82/100
# 152/152 - 1s - 8ms/step - loss: 0.0020
# Epoch 83/100
# 152/152 - 1s - 7ms/step - loss: 0.0020
# Epoch 84/100
# 152/152 - 1s - 5ms/step - loss: 0.0020
# Epoch 85/100
# 152/152 - 1s - 8ms/step - loss: 0.0020
# Epoch 86/100
# 152/152 - 1s - 4ms/step - loss: 0.0020
# Epoch 87/100
# 152/152 - 1s - 8ms/step - loss: 0.0020
# Epoch 88/100
# 152/152 - 1s - 5ms/step - loss: 0.0020
# Epoch 89/100
# 152/152 - 1s - 9ms/step - loss: 0.0020
# Epoch 90/100
# 152/152 - 1s - 5ms/step - loss: 0.0020
# Epoch 91/100
# 152/152 - 1s - 8ms/step - loss: 0.0019
# Epoch 92/100
# 152/152 - 2s - 10ms/step - loss: 0.0019
# Epoch 93/100
# 152/152 - 1s - 8ms/step - loss: 0.0019
# Epoch 94/100
# 152/152 - 1s - 5ms/step - loss: 0.0019
# Epoch 95/100
# 152/152 - 1s - 4ms/step - loss: 0.0019
# Epoch 96/100
# 152/152 - 1s - 5ms/step - loss: 0.0019
# Epoch 97/100
# 152/152 - 1s - 8ms/step - loss: 0.0019
# Epoch 98/100
# 152/152 - 1s - 5ms/step - loss: 0.0019
# Epoch 99/100
# 152/152 - 1s - 8ms/step - loss: 0.0019
# Epoch 100/100
# 152/152 - 1s - 5ms/step - loss: 0.0019
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step

# %% [markdown]
# Loss Plot

# %%
# Plot the training loss

plt.figure(figsize=(10, 6))

plt.plot(history.history['loss'], label='Training Loss', color='blue', linewidth=2)

# Annotating the plot

plt.title('Training Loss vs. Epochs', fontsize=16)

plt.xlabel('Epochs', fontsize=14)

plt.ylabel('Loss', fontsize=14)

plt.legend(fontsize=12)

plt.grid(True)

plt.show()

# %% [markdown]
# Predicted and actual values plot

# %%
# Ensure y_test is squeezed (flattened) if it has an extra dimension

y_test_flat = y_test.squeeze()

# Plot the true values and predictions

plt.figure(figsize=(12, 6))

plt.plot(y_test_flat, label="True Values", color="green", linewidth=2)

plt.plot(y_pred, label="LSTM Predictions", color="red", linewidth=2)

# Add labels, title, and legend

plt.title("LSTM Predictions vs. True Values", fontsize=16)

plt.xlabel("Time Step", fontsize=14)

plt.ylabel("Value", fontsize=14)

plt.legend(fontsize=12)

plt.grid(True)

# Show the plot

plt.show()

# %% [markdown]
# performance indicator

# %%
mse = mean_squared_error(y_test, y_pred)

rmse = np.sqrt(mse)

mape = mean_absolute_percentage_error(y_test, y_pred)

print("RMSE: ",rmse)

print("MAPE: ", mape)
# Out:
# RMSE:  0.37055847125563346
# MAPE:  0.15527134875742182

# %% [markdown]
# Fitting same model with increased time steps

# %%
n_steps=10

X1, y1 = lstm_split(stock_data_ft.values, n_steps=n_steps)

train_split=0.8

split_idx = int(np.ceil(len(X1)*train_split))

date_index = stock_data_ft.index

X_train, X_test = X1[:split_idx], X1[split_idx:]

y_train, y_test = y1[:split_idx], y1[split_idx:]

X_train_date, X_test_date = date_index[:split_idx], date_index[split_idx:-n_steps]

print(X1.shape, X_train.shape, X_test.shape, X_test_date.shape, y_test.shape)
# Out:
# (748, 10, 3) (599, 10, 3) (149, 10, 3) (149,) (149,)

# %% [markdown]
# above used model

# %%
lstm = Sequential()

lstm.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]),

              activation='relu', return_sequences=True))

lstm.add(LSTM(50, activation='relu', return_sequences=True))

lstm.add(LSTM(50, activation='relu'))

lstm.add(Dense(1))

lstm.compile(loss='mean_squared_error', optimizer='adam')

lstm.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                   │ (None, 10, 50)         │        10,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 10, 50)         │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_6 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 51,251 (200.20 KB)
#  Trainable params: 51,251 (200.20 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history=lstm.fit(X_train, y_train,epochs=100, batch_size=4,verbose=2, shuffle=False)
# Out:
# Epoch 1/100
# 150/150 - 7s - 46ms/step - loss: 0.1537
# Epoch 2/100
# 150/150 - 3s - 19ms/step - loss: 0.0895
# Epoch 3/100
# 150/150 - 4s - 29ms/step - loss: 0.0412
# Epoch 4/100
# 150/150 - 2s - 13ms/step - loss: 0.0345
# Epoch 5/100
# 150/150 - 2s - 14ms/step - loss: 0.0313
# Epoch 6/100
# 150/150 - 3s - 18ms/step - loss: 0.0286
# Epoch 7/100
# 150/150 - 3s - 18ms/step - loss: 0.0246
# Epoch 8/100
# 150/150 - 2s - 13ms/step - loss: 0.0217
# Epoch 9/100
# 150/150 - 2s - 14ms/step - loss: 0.0188
# Epoch 10/100
# 150/150 - 2s - 13ms/step - loss: 0.0176
# Epoch 11/100
# 150/150 - 2s - 13ms/step - loss: 0.0158
# Epoch 12/100
# 150/150 - 2s - 15ms/step - loss: 0.0141
# Epoch 13/100
# 150/150 - 3s - 19ms/step - loss: 0.0124
# Epoch 14/100
# 150/150 - 2s - 14ms/step - loss: 0.0111
# Epoch 15/100
# 150/150 - 2s - 13ms/step - loss: 0.0094
# Epoch 16/100
# 150/150 - 2s - 13ms/step - loss: 0.0083
# Epoch 17/100
# 150/150 - 3s - 17ms/step - loss: 0.0071
# Epoch 18/100
# 150/150 - 3s - 18ms/step - loss: 0.0063
# Epoch 19/100
# 150/150 - 4s - 29ms/step - loss: 0.0059
# Epoch 20/100
# 150/150 - 2s - 13ms/step - loss: 0.0055
# Epoch 21/100
# 150/150 - 2s - 16ms/step - loss: 0.0052
# Epoch 22/100
# 150/150 - 3s - 22ms/step - loss: 0.0050
# Epoch 23/100
# 150/150 - 2s - 15ms/step - loss: 0.0048
# Epoch 24/100
# 150/150 - 2s - 12ms/step - loss: 0.0047
# Epoch 25/100
# 150/150 - 2s - 13ms/step - loss: 0.0045
# Epoch 26/100
# 150/150 - 3s - 18ms/step - loss: 0.0044
# Epoch 27/100
# 150/150 - 3s - 18ms/step - loss: 0.0044
# Epoch 28/100
# 150/150 - 3s - 18ms/step - loss: 0.0044
# Epoch 29/100
# 150/150 - 2s - 13ms/step - loss: 0.0043
# Epoch 30/100
# 150/150 - 3s - 17ms/step - loss: 0.0040
# Epoch 31/100
# 150/150 - 3s - 17ms/step - loss: 0.0040
# Epoch 32/100
# 150/150 - 3s - 17ms/step - loss: 0.0039
# Epoch 33/100
# 150/150 - 3s - 20ms/step - loss: 0.0038
# Epoch 34/100
# 150/150 - 4s - 27ms/step - loss: 0.0039
# Epoch 35/100
# 150/150 - 3s - 17ms/step - loss: 0.0039
# Epoch 36/100
# 150/150 - 3s - 17ms/step - loss: 0.0038
# Epoch 37/100
# 150/150 - 3s - 18ms/step - loss: 0.0037
# Epoch 38/100
# 150/150 - 4s - 30ms/step - loss: 0.0036
# Epoch 39/100
# 150/150 - 2s - 13ms/step - loss: 0.0037
# Epoch 40/100
# 150/150 - 3s - 17ms/step - loss: 0.0036
# Epoch 41/100
# 150/150 - 2s - 15ms/step - loss: 0.0036
# Epoch 42/100
# 150/150 - 3s - 19ms/step - loss: 0.0036
# Epoch 43/100
# 150/150 - 4s - 30ms/step - loss: 0.0036
# Epoch 44/100
# 150/150 - 3s - 17ms/step - loss: 0.0037
# Epoch 45/100
# 150/150 - 2s - 13ms/step - loss: 0.0044
# Epoch 46/100
# 150/150 - 3s - 21ms/step - loss: 0.0047
# Epoch 47/100
# 150/150 - 2s - 13ms/step - loss: 0.0044
# Epoch 48/100
# 150/150 - 3s - 17ms/step - loss: 0.0043
# Epoch 49/100
# 150/150 - 2s - 13ms/step - loss: 0.0040
# Epoch 50/100
# 150/150 - 2s - 14ms/step - loss: 0.0038
# Epoch 51/100
# 150/150 - 3s - 22ms/step - loss: 0.0038
# Epoch 52/100
# 150/150 - 4s - 28ms/step - loss: 0.0034
# Epoch 53/100
# 150/150 - 3s - 17ms/step - loss: 0.0036
# Epoch 54/100
# 150/150 - 2s - 13ms/step - loss: 0.0038
# Epoch 55/100
# 150/150 - 3s - 21ms/step - loss: 0.0032
# Epoch 56/100
# 150/150 - 2s - 16ms/step - loss: 0.0038
# Epoch 57/100
# 150/150 - 2s - 14ms/step - loss: 0.0044
# Epoch 58/100
# 150/150 - 2s - 13ms/step - loss: 0.0049
# Epoch 59/100
# 150/150 - 2s - 13ms/step - loss: 0.0038
# Epoch 60/100
# 150/150 - 2s - 14ms/step - loss: 0.0050
# Epoch 61/100
# 150/150 - 4s - 23ms/step - loss: 0.0042
# Epoch 62/100
# 150/150 - 4s - 27ms/step - loss: 0.0043
# Epoch 63/100
# 150/150 - 2s - 13ms/step - loss: 0.0059
# Epoch 64/100
# 150/150 - 2s - 13ms/step - loss: 0.0069
# Epoch 65/100
# 150/150 - 3s - 20ms/step - loss: 0.0053
# Epoch 66/100
# 150/150 - 3s - 18ms/step - loss: 0.0052
# Epoch 67/100
# 150/150 - 2s - 13ms/step - loss: 0.0080
# Epoch 68/100
# 150/150 - 3s - 17ms/step - loss: 0.0066
# Epoch 69/100
# 150/150 - 2s - 13ms/step - loss: 0.0088
# Epoch 70/100
# 150/150 - 2s - 16ms/step - loss: 0.0123
# Epoch 71/100
# 150/150 - 3s - 20ms/step - loss: 0.0121
# Epoch 72/100
# 150/150 - 2s - 14ms/step - loss: 0.0077
# Epoch 73/100
# 150/150 - 2s - 16ms/step - loss: 0.0142
# Epoch 74/100
# 150/150 - 2s - 16ms/step - loss: 0.0210
# Epoch 75/100
# 150/150 - 2s - 13ms/step - loss: 0.0177
# Epoch 76/100
# 150/150 - 2s - 16ms/step - loss: 0.0231
# Epoch 77/100
# 150/150 - 3s - 17ms/step - loss: 0.0181
# Epoch 78/100
# 150/150 - 2s - 14ms/step - loss: 0.0094
# Epoch 79/100
# 150/150 - 2s - 16ms/step - loss: 0.0109
# Epoch 80/100
# 150/150 - 2s - 13ms/step - loss: 0.0158
# Epoch 81/100
# 150/150 - 2s - 13ms/step - loss: 0.0224
# Epoch 82/100
# 150/150 - 3s - 23ms/step - loss: 0.0196
# Epoch 83/100
# 150/150 - 4s - 28ms/step - loss: 0.0189
# Epoch 84/100
# 150/150 - 2s - 13ms/step - loss: 0.0186
# Epoch 85/100
# 150/150 - 3s - 17ms/step - loss: 0.0197
# Epoch 86/100
# 150/150 - 4s - 23ms/step - loss: 0.0191
# Epoch 87/100
# 150/150 - 2s - 14ms/step - loss: 0.0170
# Epoch 88/100
# 150/150 - 2s - 16ms/step - loss: 0.0179
# Epoch 89/100
# 150/150 - 2s - 13ms/step - loss: 0.0178
# Epoch 90/100
# 150/150 - 2s - 13ms/step - loss: 0.0182
# Epoch 91/100
# 150/150 - 3s - 22ms/step - loss: 0.0169
# Epoch 92/100
# 150/150 - 2s - 16ms/step - loss: 0.0155
# Epoch 93/100
# 150/150 - 2s - 14ms/step - loss: 0.0156
# Epoch 94/100
# 150/150 - 3s - 17ms/step - loss: 0.0156
# Epoch 95/100
# 150/150 - 2s - 16ms/step - loss: 0.0105
# Epoch 96/100
# 150/150 - 3s - 19ms/step - loss: 0.0126
# Epoch 97/100
# 150/150 - 3s - 19ms/step - loss: 0.0118
# Epoch 98/100
# 150/150 - 2s - 14ms/step - loss: 0.0132
# Epoch 99/100
# 150/150 - 2s - 13ms/step - loss: 0.0124
# Epoch 100/100
# 150/150 - 2s - 13ms/step - loss: 0.0123

# %% [markdown]
# Plotting Training Loss

# %%
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss', color='blue', linewidth=2)
# Annotating the plot
plt.title('Training Loss vs. Epochs', fontsize=16)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)
plt.show()

# %%
y_pred = lstm.predict(X_test)
# Out:
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x78888a002fc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 1s 430ms/step
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x78888a002fc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step

# %% [markdown]
# plot predict vs actual value

# %%
# Ensure y_test is squeezed (flattened) if it has an extra dimension

y_test_flat = y_test.squeeze()

# Plot the true values and predictions

plt.figure(figsize=(12, 6))

plt.plot(y_test_flat, label="True Values", color="green", linewidth=2)

plt.plot(y_pred, label="LSTM Predictions", color="red", linewidth=2)

# Add labels, title, and legend

plt.title("LSTM Predictions vs. True Values", fontsize=16)

plt.xlabel("Time Step", fontsize=14)

plt.ylabel("Value", fontsize=14)

plt.legend(fontsize=12)

plt.grid(True)

# Show the plot

plt.show()

# %%
mse = mean_squared_error(y_test, y_pred)

rmse = np.sqrt(mse)

mape = mean_absolute_percentage_error(y_test, y_pred)

print("RMSE: ",rmse)

print("MAPE: ", mape)
# Out:
# RMSE:  0.07516703186385822
# MAPE:  0.0688204839525375

# %% [markdown]
# # LSTM vs. Simple Moving Average vs. Exponential Moving Average

# %% [markdown]
# Simple Moving Average

# %%
train_split = 0.8

split_idx = int(np.ceil(len(stock_data)*train_split))

train = stock_data[['Close']].iloc[:split_idx]

test = stock_data[['Close']].iloc[split_idx:]

test_pred = np.array([train.rolling(10).mean().iloc[-1]]*len(test)).reshape((-1,1))

print('Test RMSE: %.3f' % np.sqrt(mean_squared_error(test, test_pred)))

print('Test MAPE: %.3f' % mean_absolute_percentage_error(test, test_pred))

plt.figure(figsize=(10,5))

plt.plot(test)

plt.plot(test_pred)

plt.show()
# Out:
# Test RMSE: 100.354
# Test MAPE: 0.163

# %% [markdown]
# Exponential Moving Average

# %%
from statsmodels.tsa.api import SimpleExpSmoothing

X = stock_data[['Close']].values

train_split = 0.8

split_idx = int(np.ceil(len(X)*train_split))

train = X[:split_idx]

test = X[split_idx:]

test_concat = np.array([]).reshape((0,1))

for i in range(len(test)):

  train_fit = np.concatenate((train, np.asarray(test_concat)))

  fit = SimpleExpSmoothing(np.asarray(train_fit)).fit(smoothing_level=0.1)

  test_pred = fit.forecast(1)

  test_concat = np.concatenate((np.asarray(test_concat), test_pred.reshape((-1,1))))

# The change is here: Using test_concat instead of test_pred for RMSE calculation

print('Test RMSE: %.3f' % np.sqrt(mean_squared_error(test, test_concat)))

print('Test MAPE: %.3f' % mean_absolute_percentage_error(test, test_concat))

plt.figure(figsize=(10,5))

plt.plot(test)

plt.plot(test_concat)

plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)
# Test RMSE: 100.244
# Test MAPE: 0.163

# %% [markdown]
# # Summary
# So in the case of data for stock price prediction using machine learning, SMA and EMA have similar performance and are far behind when compared to LSTMs. We can improve our LSTM model by finetuning the hyperparameters such as the number of cells, batch size, or the loss function. However, using data beyond 2019 (up to 5-10 years' worth of data) would greatly help the model.
